# %%
from PIL import Image
img = Image.open('C:/Users/Aayush/Pictures/Screenshots/Screenshot (61).png')
img1 = Image.open('C:/Users/Aayush/Pictures/Screenshots/Screenshot (61).png')
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x21F23A6E8C8>
